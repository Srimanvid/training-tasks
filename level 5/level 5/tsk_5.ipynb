# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('house-prices.csv')
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
stat=df['Price'].describe()
print('there is a stastistics for price',stat)
sata_2=df['SqFt'].describe()
print('there is a stastistics for sqft',sata_2)
df['price_per_sqft']=df['Price'] / df['SqFt']
df.head()
# Out:
# there is a stastistics for price count       128.000000
# mean     130427.343750
# std       26868.770371
# min       69100.000000
# 25%      111325.000000
# 50%      125950.000000
# 75%      148250.000000
# max      211200.000000
# Name: Price, dtype: float64
# there is a stastistics for sqft count     128.000000
# mean     2000.937500
# std       211.572431
# min      1450.000000
# 25%      1880.000000
# 50%      2000.000000
# 75%      2140.000000
# max      2590.000000
# Name: SqFt, dtype: float64
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East
#
#    divd price  price_per_sqft
# ...

# %%
plt.scatter(df['Price'],df['SqFt'],alpha=0.5)
plt.title('house price explorer')
plt.xlabel('Price')
plt.ylabel('SqFt')
plt.show()

# %%
print('data frame first five coloumns:')
print(df.head())
# Out:
# data frame first five coloumns:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood  \
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East
#
#    divd price  price_per_sqft
# 0   63.854749       63.854749
# 1   56.256158       56.256158
# 2   65.977011       65.977011
# 3   47.828283       47.828283
# 4   56.244131       56.244131
